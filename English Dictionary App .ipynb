# %%
d={}
while 1:
    
    import json
    print('*****ENGLISH DICTIONARY APP*****')
    print('''Main Menu
      1.Add a new word
      2.Find the meaning
      3.Update a word
      4.Exit
        
  Enter Choice:''')
    
    n=int(input('Choice  :'))
    
    print()
    
    if n==1:
        word=input('Enter the word  :')
        meaning=input('Enter the meaning for word  :')
        file_1=open('words.txt','w')
        d[word]=meaning
        json.dump(d,file_1)
        file_1.close()
        print('***-----------------------------***')
        print()
        continue
        
    if n==2:
        j=input('Enter the Word  :')
        for i in d:
            if i==j:
                print('Meaning is founded for the word that your searching in the dictionary','"',j,'"',':',d[i])
                break
        else:
            print('Meaning for the word you are searching','"',j,'"','is not founded in the dictionary')
        
        print('***-------------------------------***')
        print()
        continue
        
    if n==3:
        word=input('Enter the word :')
        meaning=input('Enter the meaning to update  :')       
        file_1=open('words.txt','r')
        f1=json.load(file_1)
        file_1.close()
        print(d)
        for i in d:
            if i==word:
                d[i]=meaning
                print(d)
                break
                
        else:
            file_1=open('words.txt','w')
            d[word]=meaning
            f1=json.dump(d,file_1)     
            file_1.close()
            print('After udating the meaning for the word you entered',d) 
        
        print('***-------------------------------***')
        print()
        continue
        
    if n==4:
        print('Exit')
        break
# Out:
# *****ENGLISH DICTIONARY APP*****
# Main Menu
#       1.Add a new word
#       2.Find the meaning
#       3.Update a word
#       4.Exit
#
#   Enter Choice:
# Choice  :1
#
# Enter the word  :goal
# Enter the meaning for word  :the result or achievement toward which effort is directed
# ***-----------------------------***
#
# *****ENGLISH DICTIONARY APP*****
# Main Menu
#       1.Add a new word
#       2.Find the meaning
#       3.Update a word
#       4.Exit
#
#   Enter Choice:
# Choice  :1
#
# Enter the word  :honesty
# Enter the meaning for word  :truthfulness, sincerity, or frankness.
# ***-----------------------------***
#
# *****ENGLISH DICTIONARY APP*****
# Main Menu
#       1.Add a new word
#       2.Find the meaning
#       3.Update a word
#       4.Exit
#
#   Enter Choice:
# Choice  :1
#
# Enter the word  :love
# Enter the meaning for word  :a profoundly tender, passionate affection for another person.
# ***-----------------------------***
#
# *****ENGLISH DICTIONARY APP*****
# Main Menu
#       1.Add a new word
#       2.Find the meaning
#       3.Update a word
#       4.Exit
#
#   Enter Choice:
# Choice  :2
#
# Enter the Word  :love
# Meaning is founded for the word that your searching in the dictionary " love " : a profoundly tender, passionate affection for another person.
# ***-------------------------------***
#
# *****ENGLISH DICTIONARY APP*****
# Main Menu
#       1.Add a new word
#       2.Find the meaning
#       3.Update a word
#       4.Exit
#
#   Enter Choice:
# Choice  :3
#
# Enter the word :love
# Enter the meaning to update  :an intense feeling of deep affection
# {'goal': 'the result or achievement toward which effort is directed', 'honesty': 'truthfulness, sincerity, or frankness.', 'love': 'a profoundly tender, passionate affection for another person.'}
# {'goal': 'the result or achievement toward which effort is directed', 'honesty': 'truthfulness, sincerity, or frankness.', 'love': 'an intense feeling of deep affection'}
# ***-------------------------------***
#
# *****ENGLISH DICTIONARY APP*****
# Main Menu
#       1.Add a new word
#       2.Find the meaning
#       3.Update a word
#       4.Exit
#
#   Enter Choice:
# Choice  :4
#
# Exit
